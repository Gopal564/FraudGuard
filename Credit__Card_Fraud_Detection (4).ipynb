# %% [markdown]
# # Setup and Downloading the Dataset
#
# ### Setup Kaggle Environment
#
# 1. Create a directory named `.kaggle` in your home directory:
#    ```bash
#    !mkdir ~/.kaggle
#   ```
# 2. Copy the Kaggle API key file, kaggle.json, to the newly created directory:
# ```
# !cp kaggle.json ~/.kaggle/
# ```
# 3. Set the appropriate permissions for the API key file:
# ```
# !chmod 600 ~/.kaggle/kaggle.json
# ```
# ### Download and Extract Dataset
#
# 1. Use the Kaggle CLI to download the dataset titled "Credit Card Fraud Detection" by mlg-ulb:
# ```
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# ```
# 2. Unzip the downloaded file to extract its contents:
# ```
# !unzip creditcardfraud.zip
# ```

# %%
# Mounting Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir ~/.kaggle
# !cp /content/drive/MyDrive/Colab\ Notebooks/kaggle.json /root/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets download -d mlg-ulb/creditcardfraud -p /content/drive/MyDrive/Data\ Analyst\ Projects/Credit\ Card\ Analysis

import zipfile
zipfile_obj = zipfile.ZipFile("/content/drive/MyDrive/Data Analyst Projects/Credit Card Analysis/creditcardfraud.zip")
zipfile_obj.extractall('/content/drive/MyDrive/Data Analyst Projects/Credit Card Analysis/')
zipfile_obj.close()
# !unzip creditcardfraud.zip
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# creditcardfraud.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# ### Read and Display Dataset
# The code uses the pandas library to read a CSV file named 'creditcard.csv' and displays the resulting dataset.

# %%
import pandas as pd
# Read the CSV file into a DataFrame
df = pd.read_csv('/content/drive/MyDrive/Data Analyst Projects/Credit Card Analysis/creditcard.csv')
# Display the DataFrame
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
# Count occurrences of each unique value in the 'Class' column
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# ### Class Distribution
#
# The output shows the count of each unique value in the 'Class' column.
#
# - Class 0: 284,315 occurrences
# - Class 1: 492 occurrences
#
# This information is valuable, especially in tasks like credit card fraud detection, where Class 1 often represents fraudulent transactions, and Class 0 represents non-fraudulent transactions. The imbalanced nature of the classes (with significantly more non-fraudulent transactions) is common in fraud detection datasets.

# %% [markdown]
# ### Histograms for Numerical Columns
#
# The code generates histograms for each numerical column in the dataset.

# %%
# Create histograms for each numerical column
df.hist(bins=30, figsize=(30, 30))
# Out:
# array([[<Axes: title={'center': 'Time'}>, <Axes: title={'center': 'V1'}>,
#         <Axes: title={'center': 'V2'}>, <Axes: title={'center': 'V3'}>,
#         <Axes: title={'center': 'V4'}>, <Axes: title={'center': 'V5'}>],
#        [<Axes: title={'center': 'V6'}>, <Axes: title={'center': 'V7'}>,
#         <Axes: title={'center': 'V8'}>, <Axes: title={'center': 'V9'}>,
#         <Axes: title={'center': 'V10'}>, <Axes: title={'center': 'V11'}>],
#        [<Axes: title={'center': 'V12'}>, <Axes: title={'center': 'V13'}>,
#         <Axes: title={'center': 'V14'}>, <Axes: title={'center': 'V15'}>,
#         <Axes: title={'center': 'V16'}>, <Axes: title={'center': 'V17'}>],
#        [<Axes: title={'center': 'V18'}>, <Axes: title={'center': 'V19'}>,
#         <Axes: title={'center': 'V20'}>, <Axes: title={'center': 'V21'}>,
#         <Axes: title={'center': 'V22'}>, <Axes: title={'center': 'V23'}>],
#        [<Axes: title={'center': 'V24'}>, <Axes: title={'center': 'V25'}>,
#         <Axes: title={'center': 'V26'}>, <Axes: title={'center': 'V27'}>,
#         <Axes: title={'center': 'V28'}>,
#         <Axes: title={'center': 'Amount'}>],
#        [<Axes: title={'center': 'Class'}>, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# ### Descriptive Statistics
#
# The code generates descriptive statistics for the numerical columns in the dataset.
#
# - The Amount min - 0 and max - 25691.16 and avg - 88.349619 which means their are few high values only
# - Class lies is either 0 or 1

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ### Feature Scaling with RobustScaler and Min-Max Scaling
#
# The code uses the RobustScaler from scikit-learn to scale the 'Amount' column, addressing outliers. Additionally, it applies min-max scaling to the 'Time' column to normalize its values.

# %%
from sklearn.preprocessing import RobustScaler
# Create a copy of the original DataFrame
new_df = df.copy()
# Scale the 'Amount' column using RobustScaler
new_df['Amount'] = RobustScaler().fit_transform(new_df['Amount'].to_numpy().reshape(-1, 1))
# Apply min-max scaling to the 'Time' column
time = new_df['Time']
new_df['Time'] = (time - time.min()) / (time.max() - time.min())
# Display the resulting DataFrame
new_df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0       0.000000  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1       0.000000   1.191857   0.266151  0.166480  0.448154  0.060018
# 2       0.000006  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3       0.000006  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4       0.000012  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  0.999965 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  0.999971  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  0.999977   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  0.999977  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  1.000000  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28    Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  1.783274
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724 -0.269825
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  4.983721
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  1.418291
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153  0.670579
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731 -0.296653
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527  0.038986
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561  0.641096
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533 -0.167680
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  2.724796
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %% [markdown]
# ### Shuffling Rows in the DataFrame
#
# The code shuffles the rows of the DataFrame 'new_df' to introduce randomness.

# %%
new_df = new_df.sample(frac=1, random_state=1)
new_df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 169876  0.693938 -0.611712 -0.769705 -0.149759 -0.224877  2.028577 -2.019887
# 127467  0.453377 -0.814682  1.319219  1.329415  0.027273 -0.284871 -0.653985
# 137900  0.476770 -0.318193  1.118618  0.969864 -0.127052  0.569563 -0.532484
# 21513   0.183556 -1.328271  1.018378  1.775426 -1.574193 -0.117696 -0.457733
# 134700  0.468326  1.276712  0.617120 -0.578014  0.879173  0.061706 -1.472002
# ...          ...       ...       ...       ...       ...       ...       ...
# 21440   0.183261 -2.986845 -8.663978 -1.910863  0.664058 -3.934875  0.861269
# 117583  0.432480  0.937083 -0.849673  0.524186 -0.020031 -0.606327  0.692302
# 73349   0.318852 -1.149963  1.696462  1.637114  2.658991 -0.021502  0.192287
# 267336  0.941757  1.754554 -0.699398 -0.076332  0.443915 -0.672082  0.389061
# 128037  0.454743 -0.707635  0.493302  2.648089  1.064807 -0.680271  1.183838
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 169876  0.292491 -0.523020  0.358468  ... -0.075208  0.045536  0.380739
# 127467  0.321552  0.435975 -0.704298  ... -0.128619 -0.368565  0.090660
# 137900  0.706252 -0.064966 -0.463271  ... -0.305402 -0.774704 -0.123884
# 21513   0.681867 -0.031641  0.383872  ... -0.220815 -0.419013 -0.239197
# 134700  0.373692 -0.287204 -0.084482  ... -0.160161 -0.430404 -0.076738
# ...          ...       ...       ...  ...       ...       ...       ...
# 21440   1.647511 -0.480963 -1.546866  ...  1.252092 -0.993085 -2.173147
# 117583 -0.463724  0.148857  0.785062  ... -0.143322 -0.479981 -0.237902
# 73349   0.205204  0.588754 -1.187820  ...  0.025147  0.086506 -0.262748
# 267336 -0.807534  0.202915  0.858635  ...  0.141950  0.358412  0.259748
# 128037  0.169413  0.074553  1.247988  ... -0.102350  0.323975 -0.172601
#
#              V24       V25       V26       V27       V28     Amount  Class
# 169876  0.023440 -2.220686 -0.201146  0.066501  0.221180  -0.282401      0
# 127467  0.401147 -0.261034  0.080621  0.162427  0.059456  -0.279746      0
# 137900 -0.495687 -0.018148  0.121679  0.249050  0.092516  -0.294977      0
# 21513   0.009967  0.232829  0.814177  0.098797 -0.004273  -0.084119      0
# 134700  0.258708  0.552170  0.370701 -0.034255  0.041709  -0.296793      0
# ...          ...       ...       ...       ...       ...        ...    ...
# 21440   0.145570 -0.235062 -0.227411 -0.382702  0.404045  32.002515      0
# 117583 -0.715247  0.251418  0.975406 -0.060168  0.023771   2.086495      0
# 73349   0.321538  0.341667  0.210343 -0.162047  0.031193  -0.201495      0
# 267336  0.746839 -0.560808  0.104636 -0.005853 -0.019622   1.017257      0
# 128037  0.126965 -0.001998 -0.398741 -0.385589 -0.205589   0.500245      0
#
# [284807 rows x 31 columns]

# %% [markdown]
# ### Train-Test-Validation Split and Class Distribution
#
# The code splits the shuffled DataFrame 'new_df' into three sets: training, testing, and validation.
#
#
# The class distribution is as follows:
#
# Training Set:
#
# - Class 0: 239,589 occurrences
# - Class 1: 411 occurrences
#
# Testing Set:
#
# - Class 0: 21,955 occurrences
# - Class 1: 45 occurrences
#
# Validation Set:
#
# - Class 0: 22,771 occurrences
# - Class 1: 36 occurrences
#
# These counts provide insights into the distribution of the target variable ('Class') in each set, which is crucial for understanding the balance between the two classes.

# %%
# Split the DataFrame into training, testing, and validation sets
train, test, val = new_df[:240000], new_df[240000:262000], new_df[262000:]
# Display the class distribution for each set
train["Class"].value_counts(), test["Class"].value_counts(), val["Class"].value_counts()
# Out:
# (Class
#  0    239589
#  1       411
#  Name: count, dtype: int64,
#  Class
#  0    21955
#  1       45
#  Name: count, dtype: int64,
#  Class
#  0    22771
#  1       36
#  Name: count, dtype: int64)

# %% [markdown]
# ### Converting DataFrames to NumPy Arrays
#
# The code converts the DataFrames 'train', 'test', and 'val' into NumPy arrays and prints their shapes.

# %%
# Convert DataFrames to NumPy arrays
train_np, test_np, val_np = train.to_numpy(), test.to_numpy(), val.to_numpy()
# Display the shapes of the resulting arrays
train_np.shape, test_np.shape, val_np.shape
# Out:
# ((240000, 31), (22000, 31), (22807, 31))

# %% [markdown]
# ### Separating Features and Target Variable
#
# The code separates the input features and target variable from the NumPy arrays representing the training, testing, and validation sets.

# %%
# Separate features and target variable for the training set
x_train, y_train = train_np[:, :-1], train_np[:, -1]
# Separate features and target variable for the testing set
x_test, y_test = test_np[:, :-1], test_np[:, -1]
# Separate features and target variable for the validation set
x_val, y_val = val_np[:, :-1], val_np[:, -1]
# Display the shapes of the resulting arrays
x_train.shape, y_train.shape, x_test.shape, y_test.shape, x_val.shape, y_val.shape
# Out:
# ((240000, 30), (240000,), (22000, 30), (22000,), (22807, 30), (22807,))

# %% [markdown]
# ### Logistic Regression Model Training and Evaluation
#
# The code trains a logistic regression model on the training data and evaluates its accuracy on the same training set.

# %%
# Import the Logistic Regression model from scikit-learn
from sklearn.linear_model import LogisticRegression
# Create a logistic regression model
logistic_model = LogisticRegression()
# Fit the model to the training data
logistic_model.fit(x_train, y_train)
# Evaluate the accuracy of the model on the training set
logistic_model.score(x_train, y_train)
# Out:
# 0.9992375

# %%
from sklearn.metrics import classification_report
print(classification_report(y_val, logistic_model.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     22771
#        Fraud       0.83      0.56      0.67        36
#
#     accuracy                           1.00     22807
#    macro avg       0.92      0.78      0.83     22807
# weighted avg       1.00      1.00      1.00     22807

# %%
from sklearn.metrics import ConfusionMatrixDisplay
# Generate confusion matrix
confusion_matrix = ConfusionMatrixDisplay.from_estimator(logistic_model, x_val, y_val, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')

# %% [markdown]
# ### Logistic Regression Classifier
#
# The Logistic Regression classifier shows good overall performance but has a trade-off between precision and recall for the 'Fraud' class. The model tends to be more conservative in predicting 'Fraud,' resulting in a lower recall.

# %% [markdown]
# ### Performance on the testing data

# %%
print(classification_report(y_test, logistic_model.predict(x_test), target_names=['Not Fraud', 'Fraud']))
confusion_matrix = ConfusionMatrixDisplay.from_estimator(logistic_model, x_test, y_test, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     21955
#        Fraud       0.88      0.67      0.76        45
#
#     accuracy                           1.00     22000
#    macro avg       0.94      0.83      0.88     22000
# weighted avg       1.00      1.00      1.00     22000

# %% [markdown]
# ### Shallow Neural Net
# This code defines a neural network with one hidden layer (2 units) and uses the ReLU activation function. Batch normalization is applied to normalize the inputs. The output layer has 1 unit with a sigmoid activation function for binary classification. The model is compiled using the Adam optimizer and binary crossentropy loss.
#
# During training, a model checkpoint is employed to save the weights of the model with the best performance on the validation set. The training is done for 5 epochs.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint

# Create a shallow neural network
shallow_nn = Sequential()
# Add an input layer with the number of features in the input data
shallow_nn.add(InputLayer((x_train.shape[1],)))
# Add a dense layer with 2 units and ReLU activation function
shallow_nn.add(Dense(2, 'relu'))
# Add Batch Normalization layer
shallow_nn.add(BatchNormalization())
# Add the output layer with 1 unit and sigmoid activation function for binary classification
shallow_nn.add(Dense(1, 'sigmoid'))

# Define a model checkpoint to save the best weights during training
checkpoint = ModelCheckpoint('shallow_nn.keras', save_best_only=True)
# Compile the model using the Adam optimizer and binary crossentropy loss and use accuracy as a metric
shallow_nn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Display a summary of the model architecture
shallow_nn.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 2)              │            62 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 2)              │             8 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73 (292.00 B)
#  Trainable params: 69 (276.00 B)
#  Non-trainable params: 4 (16.00 B)

# %%
# Train the model on the training set, validate on the validation set, and save the best weights
shallow_nn.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=5, callbacks=checkpoint)
# Out:
# Epoch 1/5
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - accuracy: 0.9339 - loss: 0.1740 - val_accuracy: 0.9993 - val_loss: 0.0075
# Epoch 2/5
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - accuracy: 0.9993 - loss: 0.0036 - val_accuracy: 0.9993 - val_loss: 0.0074
# Epoch 3/5
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.9993 - loss: 0.0032 - val_accuracy: 0.9992 - val_loss: 0.0078
# Epoch 4/5
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.9994 - loss: 0.0029 - val_accuracy: 0.9991 - val_loss: 0.0077
# Epoch 5/5
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9993 - loss: 0.0033 - val_accuracy: 0.9991 - val_loss: 0.0075

# %%
# Function to make predictions using the trained model
def neural_net_predictions(model, x):
  return (model.predict(x).flatten() > 0.5).astype(int)

# neural_net_predictions(shallow_nn, x_val)

# %%
print(classification_report(y_val, neural_net_predictions(shallow_nn, x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     22771
#        Fraud       0.71      0.75      0.73        36
#
#     accuracy                           1.00     22807
#    macro avg       0.86      0.87      0.86     22807
# weighted avg       1.00      1.00      1.00     22807

# %%
# confusion matrix for the shallow neural network
confusion_matrix_nn = ConfusionMatrixDisplay.from_predictions(y_val, neural_net_predictions(shallow_nn, x_val), display_labels=['Not Fraud', 'Fraud'], cmap='Blues')
# Out:
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ### Shallow NN Classifier
#
# The Shallow NN classifier shows good overall performance but has a trade-off between precision and recall for the 'Fraud' class. The model tends to be more conservative in predicting 'Fraud,' resulting in a lower recall.

# %% [markdown]
# ### Performance on the testing data

# %%
print(classification_report(y_test, neural_net_predictions(shallow_nn, x_test), target_names=['Not Fraud', 'Fraud']))
confusion_matrix_nn = ConfusionMatrixDisplay.from_predictions(y_test, neural_net_predictions(shallow_nn, x_test), display_labels=['Not Fraud', 'Fraud'], cmap='Blues')
# Out:
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     21955
#        Fraud       0.88      0.78      0.82        45
#
#     accuracy                           1.00     22000
#    macro avg       0.94      0.89      0.91     22000
# weighted avg       1.00      1.00      1.00     22000
#
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
from sklearn.ensemble import RandomForestClassifier
# Create a Random Forest classifier with a maximum depth of 2 and parallel processing
rf = RandomForestClassifier(max_depth=2, n_jobs=-1)
# Fit the model to the training data
rf.fit(x_train, y_train)

print(classification_report(y_val, rf.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     22771
#        Fraud       0.81      0.47      0.60        36
#
#     accuracy                           1.00     22807
#    macro avg       0.90      0.74      0.80     22807
# weighted avg       1.00      1.00      1.00     22807

# %%
# Generate confusion matrix for the Random Forest classifier
confusion_matrix_rf = ConfusionMatrixDisplay.from_estimator(rf, x_val, y_val, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')

# %% [markdown]
# ### Random Forest Classifier
#
# The Random Forest classifier shows good overall performance but has a trade-off between precision and recall for the 'Fraud' class. The model tends to be more conservative in predicting 'Fraud,' resulting in a lower recall.

# %% [markdown]
# ### Performance on the testing data

# %%
print(classification_report(y_test, rf.predict(x_test), target_names=['Not Fraud', 'Fraud']))
confusion_matrix_rf = ConfusionMatrixDisplay.from_estimator(rf, x_test, y_test, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     21955
#        Fraud       0.90      0.60      0.72        45
#
#     accuracy                           1.00     22000
#    macro avg       0.95      0.80      0.86     22000
# weighted avg       1.00      1.00      1.00     22000

# %%
from sklearn.ensemble import GradientBoostingClassifier
# Create a Gradient Boosting Classifier with specific hyperparameters
gbc = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0, max_depth=1, random_state=0)
# Fit the model to the training data
gbc.fit(x_train, y_train)

print(classification_report(y_val, gbc.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     22771
#        Fraud       0.67      0.67      0.67        36
#
#     accuracy                           1.00     22807
#    macro avg       0.83      0.83      0.83     22807
# weighted avg       1.00      1.00      1.00     22807

# %%
# confusion matrix for the Gradient Boosting Classifier
confusion_matrix_gbc = ConfusionMatrixDisplay.from_estimator(gbc, x_val, y_val, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')

# %% [markdown]
# ### Gradient Boosting Classifier
#
# The model performs exceptionally well on the majority class ('Not Fraud'), achieving perfect precision and recall.
#
# For the minority class ('Fraud'), precision and recall are balanced but lower than the majority class.
#
# The overall high accuracy might be influenced by the class imbalance, as predicting the majority class accurately contributes significantly.

# %% [markdown]
# ### Performance on testing data

# %%
print(classification_report(y_test, gbc.predict(x_test), target_names=['Not Fraud', 'Fraud']))
confusion_matrix_gbc = ConfusionMatrixDisplay.from_estimator(gbc, x_test, y_test, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     21955
#        Fraud       0.82      0.69      0.75        45
#
#     accuracy                           1.00     22000
#    macro avg       0.91      0.84      0.87     22000
# weighted avg       1.00      1.00      1.00     22000

# %%
from sklearn.svm import LinearSVC
# Create a Linear Support Vector Machine classifier with balanced class weights
svc = LinearSVC(class_weight='balanced')
# Fit the model to the training data
svc.fit(x_train, y_train)

print(classification_report(y_val, svc.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      0.98      0.99     22771
#        Fraud       0.07      0.97      0.14        36
#
#     accuracy                           0.98     22807
#    macro avg       0.54      0.98      0.56     22807
# weighted avg       1.00      0.98      0.99     22807

# %%
# confusion matrix for the Linear SVC
confusion_matrix_svc = ConfusionMatrixDisplay.from_estimator(svc, x_val, y_val, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')

# %% [markdown]
# ### Linear Support Vector Machine classifier
#
# The SVM with a linear kernel and balanced class weights achieved high precision for 'Not Fraud' but relatively lower precision for 'Fraud.' The recall for 'Fraud' is decent, contributing to a balanced F1-Score.

# %% [markdown]
# ### Performance on the testing data

# %%
print(classification_report(y_test, svc.predict(x_test), target_names=['Not Fraud', 'Fraud']))
confusion_matrix_svc = ConfusionMatrixDisplay.from_estimator(svc, x_test, y_test, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      0.98      0.99     21955
#        Fraud       0.09      0.91      0.17        45
#
#     accuracy                           0.98     22000
#    macro avg       0.55      0.95      0.58     22000
# weighted avg       1.00      0.98      0.99     22000

# %%
# Install the package
! pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.15.3)

# %%
# Defining the  Classifier
from xgboost import XGBClassifier
classifier = XGBClassifier(n_estimators = 1000, max_depth =10, learning_rate = 0.1, use_label_encoder=False)

# Training the XGB classifier
classifier.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:47:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# Making predictions with the val data
y_pred = classifier.predict(x_val)
# Combining the actual and predicted values
pd.DataFrame(data={'Actual Labels': y_val, 'Predicted Labels': y_pred}).head()

# Confusion matrix
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(classifier, x_val, y_val, cmap='Blues')

# Accuracy score
from sklearn.metrics import accuracy_score
print('The accuracy score for the given: ', accuracy_score(y_val, y_pred))

# Classification report
from sklearn.metrics import classification_report
print(classification_report(y_val, y_pred))
# Out:
# The accuracy score for the given:  0.9994299995615381
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     22771
#          1.0       0.87      0.75      0.81        36
#
#     accuracy                           1.00     22807
#    macro avg       0.94      0.87      0.90     22807
# weighted avg       1.00      1.00      1.00     22807

# %% [markdown]
# ### Xgboost classifier
#
# The Xgboost classifier achieved high precision for 'Not Fraud' but relatively lower precision for 'Fraud.' The recall for 'Fraud' is decent, contributing to a balanced F1-Score.

# %% [markdown]
# ### Testing the test data

# %%
# Test Data
# Making predictions with the val data
y_pred = classifier.predict(x_test)
# Combining the actual and predicted values
pd.DataFrame(data={'Actual Labels': y_test, 'Predicted Labels': y_pred}).head()

# Confusion matrix
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(classifier, x_test, y_test, cmap='Blues')

# Accuracy score
from sklearn.metrics import accuracy_score
print('The accuracy score for the given: ', accuracy_score(y_test, y_pred))

# Classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# The accuracy score for the given:  0.9995
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     21955
#          1.0       0.95      0.80      0.87        45
#
#     accuracy                           1.00     22000
#    macro avg       0.97      0.90      0.93     22000
# weighted avg       1.00      1.00      1.00     22000

# %% [markdown]
# ## Dealing with Class Imbalance in Data
#
# ### Overview
# In classification problems, class imbalance can pose challenges as the model may be biased towards the majority class. This imbalance can affect the model's ability to accurately predict the minority class.
#
# ### Handling Class Imbalance in the Dataset
#
# In order to address the issue of class imbalance in the dataset, a strategic approach is taken to create a balanced dataset with equal representation of both 'Fraud' and 'Not Fraud' cases.

# %% [markdown]
# #### Dataset Division
#
# The initial step involves dividing the dataset into two subsets based on the class labels:

# %%
# Code to divide the dataset
not_frauds = new_df.query("Class == 0")
frauds = new_df.query("Class == 1")
# Checking it worked or not
not_frauds['Class'].value_counts(), frauds['Class'].value_counts()
# Out:
# (Class
#  0    284315
#  Name: count, dtype: int64,
#  Class
#  1    492
#  Name: count, dtype: int64)

# %% [markdown]
# ### Creating a Balanced Dataset
#
# To address the class imbalance in the original dataset, a balanced dataset is constructed by combining equal instances of 'Fraud' and 'Not Fraud' cases.

# %%
# Code to create a balanced dataset
balanced_df = pd.concat([frauds, not_frauds.sample(len(frauds), random_state=1)])
# Check class distribution in the balanced dataset
balanced_df['Class'].value_counts()
# Out:
# Class
# 1    492
# 0    492
# Name: count, dtype: int64

# %% [markdown]
# ### Shuffling the Balanced Dataset
#
# To ensure randomness in the balanced dataset, shuffling is performed. This step is crucial to eliminate any potential ordering bias in the data.

# %%
# To shuffle the balanced dataset
balanced_df = balanced_df.sample(frac=1, random_state=1)
# Display the shuffled balanced dataset
balanced_df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 18372   0.170309 -1.762593  0.256143  1.683125 -1.279233 -1.902762  1.004210
# 96341   0.380388  1.227614 -0.668974 -0.271785 -0.589440 -0.604795 -0.350285
# 248296  0.890522 -0.613696  3.698772 -5.534941  5.620486  1.649263 -2.335145
# 264328  0.933932 -0.011624  0.640413  0.868046 -0.505279  0.261938  0.223098
# 208904  0.794730 -0.679341  1.217389 -0.316778 -1.086725  0.855349 -0.980760
# ...          ...       ...       ...       ...       ...       ...       ...
# 81557   0.341393 -4.502731 -3.876484  1.341248  0.113400  0.189428 -0.560985
# 276071  0.965803  2.091900 -0.757459 -1.192258 -0.755458 -0.620324 -0.322077
# 175971  0.709373  1.972989  0.157281 -1.715078  1.207451  0.681612 -0.615282
# 27738   0.200727 -2.439237  2.591458 -2.840126  1.286244 -1.777016 -1.436139
# 156988  0.632535  0.745153  2.809299 -5.825406  5.835566  0.512320 -0.615622
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 18372  -1.009748 -2.432546  0.458860  ...  2.493579  0.320829 -0.535481
# 96341  -0.486365 -0.010809 -0.794944  ... -0.026055 -0.295255 -0.180459
# 248296 -0.907188  0.706362 -3.747646  ...  0.319261 -0.471379 -0.075890
# 264328  0.239049  0.150877  0.225142  ...  0.069401  0.268024  0.261459
# 208904  0.970589  0.133116 -0.357671  ... -0.083048 -0.137032 -0.238920
# ...          ...       ...       ...  ...       ...       ...       ...
# 81557  -0.140478  0.684651  0.475363  ... -0.140218  0.049411  2.313731
# 276071 -1.082511  0.117200 -0.140927  ...  0.288253  0.831939  0.142007
# 175971  0.601791 -0.291935 -0.132265  ...  0.098640  0.467533 -0.078973
# 27738  -2.206056 -2.282725 -0.292885  ...  1.774460 -0.771390  0.065727
# 156988 -2.916576  0.776710 -1.878832  ...  0.284841 -0.874383 -0.083995
#
#              V24       V25       V26       V27       V28    Amount  Class
# 18372   0.499401 -0.915196 -0.423434  0.107049  0.175922  2.906449      0
# 96341  -0.436539  0.494649 -0.283738 -0.001128  0.035075  1.062111      1
# 248296 -0.667909 -0.642848  0.070600  0.488410  0.292345 -0.307413      1
# 264328  0.683742 -1.567901 -0.816674  0.185781  0.283021 -0.272619      0
# 208904 -0.617244  0.039020 -0.081848  0.234633  0.128382 -0.307273      0
# ...          ...       ...       ...       ...       ...       ...    ...
# 81557   0.252330  0.307219  0.859051  0.184033 -0.308269  4.227625      0
# 276071  0.592615 -0.196143 -0.136676  0.020182 -0.015470 -0.028645      1
# 175971 -0.371882  0.486038 -0.490665 -0.018374 -0.070911  0.075735      0
# 27738   0.103916 -0.057578  0.242652 -0.268649 -0.743713  1.443443      1
# 156988 -0.651442  0.454594  0.050376  0.756953  0.383869 -0.307413      1
#
# [984 rows x 31 columns]

# %% [markdown]
# ### Creating Train, Test, and Validation Sets from the Shuffled Balanced Dataset
#
# To further prepare the data, subsets for training, testing, and validation are created from the shuffled balanced dataset.

# %%
# Coverting them to numpy array
balanced_df_np = balanced_df.to_numpy()
# To split the shuffled balanced dataset into train, test, and validation sets
x_train_b, y_train_b = balanced_df_np[:700, :-1], balanced_df_np[:700, -1].astype(int)
x_test_b, y_test_b = balanced_df_np[700:842, :-1], balanced_df_np[700:842, -1].astype(int)
x_val_b, y_val_b = balanced_df_np[842:, :-1], balanced_df_np[842:, -1].astype(int)
# Display the shapes of the subsets
x_train_b.shape, y_train_b.shape, x_test_b.shape, y_test_b.shape, x_val_b.shape, y_val_b.shape
# Out:
# ((700, 30), (700,), (142, 30), (142,), (142, 30), (142,))

# %% [markdown]
# ### Class Distribution in Balanced Train, Test, and Validation Sets
#
# Let's examine the class distribution in the balanced training, testing, and validation sets.
#
# The output shows the count of instances for each class in the respective sets:
#
# Training Set:
#
# - Class 0: 347 instances
# - Class 1: 353 instances
#
# Testing Set:
#
# - Class 0: 73 instances
# - Class 1: 69 instances
#
# Validation Set:
#
# - Class 0: 72 instances
# - Class 1: 70 instances
#
# These counts reflect the balanced nature of the subsets, with an equal representation of both classes.

# %%
pd.Series(y_train_b).value_counts(), pd.Series(y_test_b).value_counts(), pd.Series(y_val_b).value_counts()
# Out:
# (1    353
#  0    347
#  Name: count, dtype: int64,
#  0    73
#  1    69
#  Name: count, dtype: int64,
#  0    72
#  1    70
#  Name: count, dtype: int64)

# %% [markdown]
# ### Logistic Regression on Balanced Data
#
# Let's train a Logistic Regression model on the balanced training set (`x_train_b`, `y_train_b`) and evaluate its performance on the balanced validation set (`x_val_b`, `y_val_b`).
#
# - Precision measures the accuracy of the positive predictions made by the model.
#
# - Recall (Sensitivity) measures the ability of the model to capture all positive instances.
#
# - The F1-score is the harmonic mean of precision and recall, providing a balanced measure.
#
# #### Comparison with the Imbalanced Dataset:
#
# When comparing these results with those obtained from the imbalanced dataset, the key improvement is seen in the model's ability to correctly predict instances of the minority class ('Fraud'). In imbalanced datasets, models tend to be biased towards the majority class, leading to lower performance on the minority class. In the balanced dataset, precision, recall, and F1-score for both classes are more balanced.
#
# It's important to note that the accuracy metric alone might not be a reliable indicator of model performance, especially in imbalanced datasets. The classification report provides a more comprehensive view by considering precision and recall for each class.

# %%
# @title
# To train Logistic Regression on balanced data
logistic_model_b = LogisticRegression()
logistic_model_b.fit(x_train_b, y_train_b)
# Evaluate the model on the balanced validation set
logistic_model_b.score(x_train_b, y_train_b)

# Display the classification report for the balanced validation set
print(classification_report(y_val_b, logistic_model_b.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.96      0.93      0.94        72
#        Fraud       0.93      0.96      0.94        70
#
#     accuracy                           0.94       142
#    macro avg       0.94      0.94      0.94       142
# weighted avg       0.94      0.94      0.94       142

# %%
confusion_matrix = ConfusionMatrixDisplay.from_estimator(logistic_model_b, x_val_b, y_val_b, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')

# %% [markdown]
# ### Shallow Neural Network on Balanced Data
#
# A shallow neural network is trained on the balanced training set (`x_train_b`, `y_train_b`) and evaluated on the balanced validation set (`x_val_b`, `y_val_b`).
#
#
# These metrics indicate a balanced performance, with a notable ability to correctly identify instances of both classes. Compared to the logistic regression model, the shallow neural network shows competitive results and may offer advantages in capturing complex patterns in the data.
#
# It's important to consider the trade-offs between precision and recall based on the specific goals of the classification task. Further fine-tuning or exploration of more complex models may lead to even better performance.

# %%
# To create and train a shallow neural network on balanced data
shallow_nn_b = Sequential()
shallow_nn_b.add(InputLayer((x_train_b.shape[1],)))
shallow_nn_b.add(Dense(2, 'relu'))
shallow_nn_b.add(BatchNormalization())
shallow_nn_b.add(Dense(1, 'sigmoid'))

checkpoint_b = ModelCheckpoint('shallow_nn_b.keras', save_best_only=True)
shallow_nn_b.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display the summary of the model architecture
shallow_nn_b.summary()

# Train the model on balanced data and save the best weights
shallow_nn_b.fit(x_train_b, y_train_b, validation_data=(x_val_b, y_val_b), epochs=40, callbacks=checkpoint)


print(classification_report(y_val_b, neural_net_predictions(shallow_nn_b, x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 2)              │            62 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 2)              │             8 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73 (292.00 B)
#  Trainable params: 69 (276.00 B)
#  Non-trainable params: 4 (16.00 B)
# Epoch 1/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.1897 - loss: 1.3209 - val_accuracy: 0.2042 - val_loss: 2.0640
# Epoch 2/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.1807 - loss: 1.2549 - val_accuracy: 0.1761 - val_loss: 1.5871
# Epoch 3/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2062 - loss: 1.1962 - val_accuracy: 0.1690 - val_loss: 1.3469
# Epoch 4/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.2564 - loss: 1.1021 - val_accuracy: 0.2394 - val_loss: 1.1839
# Epoch 5/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2453 - loss: 1.0787 - val_accuracy: 0.3521 - val_loss: 1.0503
# Epoch 6/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3183 - loss: 1.0042 - val_accuracy: 0.4648 - val_loss: 0.8874
# Epoch 7/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4677 - loss: 0.8916 - val_accuracy: 0.5563 - val_loss: 0.7358
# Epoch 8/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5984 - loss: 0.7294 - val_accuracy: 0.6127 - val_loss: 0.6787
# Epoch 9/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7216 - loss: 0.6286 - val_accuracy: 0.6338 - val_loss: 0.6576
# Epoch 10/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6989 - loss: 0.6279 - val_accuracy: 0.6549 - val_loss: 0.6435
# Epoch 11/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7109 - loss: 0.6131 - val_accuracy: 0.6761 - val_loss: 0.6267
# Epoch 12/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7440 - loss: 0.5908 - val_accuracy: 0.6901 - val_loss: 0.6138
# Epoch 13/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7192 - loss: 0.5767 - val_accuracy: 0.6972 - val_loss: 0.6008
# Epoch 14/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7401 - loss: 0.5734 - val_accuracy: 0.7113 - val_loss: 0.5829
# Epoch 15/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7334 - loss: 0.5912 - val_accuracy: 0.7394 - val_loss: 0.5661
# Epoch 16/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7652 - loss: 0.5401 - val_accuracy: 0.7535 - val_loss: 0.5431
# Epoch 17/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7770 - loss: 0.5062 - val_accuracy: 0.7606 - val_loss: 0.5280
# Epoch 18/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8118 - loss: 0.4993 - val_accuracy: 0.7746 - val_loss: 0.5139
# Epoch 19/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8220 - loss: 0.4816 - val_accuracy: 0.8028 - val_loss: 0.4972
# Epoch 20/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8063 - loss: 0.4787 - val_accuracy: 0.8028 - val_loss: 0.4808
# Epoch 21/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8477 - loss: 0.4402 - val_accuracy: 0.8380 - val_loss: 0.4611
# Epoch 22/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8319 - loss: 0.4485 - val_accuracy: 0.8592 - val_loss: 0.4423
# Epoch 23/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8494 - loss: 0.4140 - val_accuracy: 0.8732 - val_loss: 0.4255
# Epoch 24/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8560 - loss: 0.4096 - val_accuracy: 0.8732 - val_loss: 0.4101
# Epoch 25/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8563 - loss: 0.3941 - val_accuracy: 0.8732 - val_loss: 0.3956
# Epoch 26/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8847 - loss: 0.3556 - val_accuracy: 0.8944 - val_loss: 0.3818
# Epoch 27/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8609 - loss: 0.3718 - val_accuracy: 0.8944 - val_loss: 0.3700
# Epoch 28/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8705 - loss: 0.3563 - val_accuracy: 0.8944 - val_loss: 0.3597
# Epoch 29/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8842 - loss: 0.3362 - val_accuracy: 0.8944 - val_loss: 0.3501
# Epoch 30/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8902 - loss: 0.3201 - val_accuracy: 0.8944 - val_loss: 0.3417
# Epoch 31/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9234 - loss: 0.3033 - val_accuracy: 0.8944 - val_loss: 0.3329
# Epoch 32/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9035 - loss: 0.3074 - val_accuracy: 0.8944 - val_loss: 0.3247
# Epoch 33/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9114 - loss: 0.2862 - val_accuracy: 0.8944 - val_loss: 0.3186
# Epoch 34/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9054 - loss: 0.2921 - val_accuracy: 0.8944 - val_loss: 0.3129
# Epoch 35/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9076 - loss: 0.2811 - val_accuracy: 0.8944 - val_loss: 0.3053
# Epoch 36/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9265 - loss: 0.2732 - val_accuracy: 0.8944 - val_loss: 0.3001
# Epoch 37/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9223 - loss: 0.2576 - val_accuracy: 0.8944 - val_loss: 0.2957
# Epoch 38/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9166 - loss: 0.2560 - val_accuracy: 0.8944 - val_loss: 0.2904
# Epoch 39/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9106 - loss: 0.2487 - val_accuracy: 0.8873 - val_loss: 0.2872
# Epoch 40/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9236 - loss: 0.2411 - val_accuracy: 0.8944 - val_loss: 0.2853
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#               precision    recall  f1-score   support
#
#    Not Fraud       0.95      0.83      0.89        72
#        Fraud       0.85      0.96      0.90        70
#
#     accuracy                           0.89       142
#    macro avg       0.90      0.90      0.89       142
# weighted avg       0.90      0.89      0.89       142

# %%
confusion_matrix = ConfusionMatrixDisplay.from_predictions(y_val_b, neural_net_predictions(shallow_nn_b, x_val_b), display_labels=['Not Fraud', 'Fraud'], cmap='Blues')
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# ### Random Forest Classifier on Balanced Data
#
# A Random Forest classifier is trained on the balanced training set (`x_train_b`, `y_train_b`).
#
# The Random Forest classifier demonstrates a strong ability to correctly classify both classes. The precision, recall, and F1-score for both 'Not Fraud' and 'Fraud' are balanced, contributing to an impressive overall accuracy of 94%.
#
# Comparing these results with the Shallow Neural Network and Logistic Regression, the Random Forest model showcases competitive performance and is well-suited for the balanced dataset.

# %%
# To create and train a Random Forest Classifier on balanced data
rf_b = RandomForestClassifier(max_depth=2, n_jobs=-1)
rf_b.fit(x_train_b, y_train_b)

print(classification_report(y_val_b, rf_b.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.93      0.97      0.95        72
#        Fraud       0.97      0.93      0.95        70
#
#     accuracy                           0.95       142
#    macro avg       0.95      0.95      0.95       142
# weighted avg       0.95      0.95      0.95       142

# %%
confusion_matrix = ConfusionMatrixDisplay.from_estimator(rf_b, x_val_b, y_val_b, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')

# %% [markdown]
# ### Gradient Boosting Classifier on Balanced Data
#
# A Gradient Boosting Classifier is trained on the balanced training set (`x_train_b`, `y_train_b`).
#
# These metrics indicate a well-performing Gradient Boosting Classifier on the balanced dataset. The model demonstrates a high ability to correctly classify instances of both 'Not Fraud' and 'Fraud', contributing to a balanced F1-score and accuracy.

# %%
# To create and train a Gradient Boosting Classifier on balanced data
gbc_b = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0, max_depth=1, random_state=0)
gbc_b.fit(x_train_b, y_train_b)

print(classification_report(y_val_b, gbc_b.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.98      0.86      0.92        72
#        Fraud       0.87      0.99      0.93        70
#
#     accuracy                           0.92       142
#    macro avg       0.93      0.92      0.92       142
# weighted avg       0.93      0.92      0.92       142

# %%
confusion_matrix = ConfusionMatrixDisplay.from_estimator(gbc_b, x_val_b, y_val_b, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')

# %% [markdown]
# ### Linear Support Vector Machine classifier on Balanced Data
#
# A Linear Support Vector Machine classifier is trained on the balanced training set (`x_train_b`, `y_train_b`).
#
# These metrics indicate a strong performance by the Linear SVM classifier on the balanced dataset. The model demonstrates a balanced ability to correctly classify instances of both 'Not Fraud' and 'Fraud', contributing to a high F1-score and accuracy.

# %%
# To create and train a Linear Support Vector Machine classifier on balanced data
svc_b = LinearSVC()
svc_b.fit(x_train_b, y_train_b)

print(classification_report(y_val_b, svc_b.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.96      0.93      0.94        72
#        Fraud       0.93      0.96      0.94        70
#
#     accuracy                           0.94       142
#    macro avg       0.94      0.94      0.94       142
# weighted avg       0.94      0.94      0.94       142

# %%
confusion_matrix = ConfusionMatrixDisplay.from_estimator(svc_b, x_val_b, y_val_b, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')

# %% [markdown]
# ### Xgboost classifier on Balanced Data
#
# A Xboost classifier is trained on the balanced training set (`x_train_b`, `y_train_b`).
#
# These metrics indicate a strong performance by the Xgboost classifier on the balanced dataset. The model demonstrates a balanced ability to correctly classify instances of both 'Not Fraud' and 'Fraud', contributing to a high F1-score and accuracy.

# %%
classifier_b = XGBClassifier(n_estimators = 1000, max_depth =10, learning_rate = 0.1, use_label_encoder=False)

# Training the XGB classifier_b
classifier_b.fit(x_train_b, y_train_b)

# Making predictions with the val data
y_pred = classifier_b.predict(x_val_b)
# Combining the actual and predicted values
pd.DataFrame(data={'Actual Labels': y_val_b, 'Predicted Labels': y_pred}).head()

# Classification report
from sklearn.metrics import classification_report
print(classification_report(y_val_b, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:48:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94        72
#            1       0.93      0.94      0.94        70
#
#     accuracy                           0.94       142
#    macro avg       0.94      0.94      0.94       142
# weighted avg       0.94      0.94      0.94       142

# %%
confusion_matrix = ConfusionMatrixDisplay.from_estimator(classifier_b, x_val_b, y_val_b, cmap='Blues')

# %% [markdown]
# # Test Metrics for Logistic Regression on Balanced Test Set
#
# These metrics indicate that the Logistic Regression model generalizes well to the balanced test set, maintaining a balanced performance in correctly classifying instances of both 'Not Fraud' and 'Fraud'.

# %%
#Test
print("Logistic Metric on Test")
print(classification_report(y_test_b, logistic_model_b.predict(x_test_b), target_names=['Not Fraud', 'Fraud']))
confusion_matrix = ConfusionMatrixDisplay.from_estimator(logistic_model_b, x_test_b, y_test_b, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')
# Out:
# Logistic Metric on Test
#               precision    recall  f1-score   support
#
#    Not Fraud       0.92      0.96      0.94        73
#        Fraud       0.95      0.91      0.93        69
#
#     accuracy                           0.94       142
#    macro avg       0.94      0.94      0.94       142
# weighted avg       0.94      0.94      0.94       142

# %% [markdown]
# # Test Metrics for Shallow Neural Network on Balanced Test Set
#
# These metrics indicate the performance of the Shallow Neural Network on the balanced test set. The model demonstrates a reasonable ability to correctly classify instances of both 'Not Fraud' and 'Fraud', contributing to a balanced F1-score and accuracy.

# %%
print("Shallow Neural Net Metric on Test")
print(classification_report(y_test_b, neural_net_predictions(shallow_nn_b ,x_test_b), target_names=['Not Fraud', 'Fraud']))
confusion_matrix = ConfusionMatrixDisplay.from_predictions(y_test_b, neural_net_predictions(shallow_nn_b, x_test_b), display_labels=['Not Fraud', 'Fraud'], cmap='Blues')
# Out:
# Shallow Neural Net Metric on Test
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#               precision    recall  f1-score   support
#
#    Not Fraud       0.91      0.86      0.89        73
#        Fraud       0.86      0.91      0.89        69
#
#     accuracy                           0.89       142
#    macro avg       0.89      0.89      0.89       142
# weighted avg       0.89      0.89      0.89       142
#
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# # Test Metrics for Random Forest Classifier on Balanced Test Set
#
# These metrics demonstrate the performance of the Random Forest Classifier on the balanced test set. The model exhibits a balanced ability to correctly classify instances of both 'Not Fraud' and 'Fraud', contributing to a high F1-score and accuracy.

# %%
print("RandomForest Classifier Metric on Test")
print(classification_report(y_test_b, rf_b.predict(x_test_b), target_names=['Not Fraud', 'Fraud']))
confusion_matrix = ConfusionMatrixDisplay.from_estimator(rf_b, x_test_b, y_test_b, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')
# Out:
# RandomForest Classifier Metric on Test
#               precision    recall  f1-score   support
#
#    Not Fraud       0.91      0.99      0.95        73
#        Fraud       0.98      0.90      0.94        69
#
#     accuracy                           0.94       142
#    macro avg       0.95      0.94      0.94       142
# weighted avg       0.95      0.94      0.94       142

# %% [markdown]
# # Test Metrics for Gradient Boosting Classifier on Balanced Test Set
#
# These metrics illustrate the performance of the Gradient Boosting Classifier on the balanced test set. The model displays a balanced ability to correctly classify instances of both 'Not Fraud' and 'Fraud', resulting in a high F1-score and accuracy.

# %%
print("Gradient Boosting Classifier Metric on Test")
print(classification_report(y_test_b, gbc_b.predict(x_test_b), target_names=['Not Fraud', 'Fraud']))
confusion_matrix = ConfusionMatrixDisplay.from_estimator(gbc_b, x_test_b, y_test_b, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')
# Out:
# Gradient Boosting Classifier Metric on Test
#               precision    recall  f1-score   support
#
#    Not Fraud       0.92      0.90      0.91        73
#        Fraud       0.90      0.91      0.91        69
#
#     accuracy                           0.91       142
#    macro avg       0.91      0.91      0.91       142
# weighted avg       0.91      0.91      0.91       142

# %% [markdown]
# # Test Metrics for Linear Support Vector Machine (LinearSVC) on Balanced Test Set
#
# These metrics showcase the performance of the Linear Support Vector Machine (LinearSVC) on the balanced test set. The model demonstrates a balanced ability to correctly classify instances of both 'Not Fraud' and 'Fraud', resulting in a high F1-score and accuracy.

# %%
print("LinearSVC Metric on Test")
print(classification_report(y_test_b, svc_b.predict(x_test_b), target_names=['Not Fraud', 'Fraud']))
confusion_matrix = ConfusionMatrixDisplay.from_estimator(svc_b, x_test_b, y_test_b, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')
# Out:
# LinearSVC Metric on Test
#               precision    recall  f1-score   support
#
#    Not Fraud       0.92      0.95      0.93        73
#        Fraud       0.94      0.91      0.93        69
#
#     accuracy                           0.93       142
#    macro avg       0.93      0.93      0.93       142
# weighted avg       0.93      0.93      0.93       142

# %% [markdown]
# # Test Metrics for Xgboost on Balanced Test Set
#
# These metrics showcase the performance of the xgboost classifier on the balanced test set. The model demonstrates a balanced ability to correctly classify instances of both 'Not Fraud' and 'Fraud', resulting in a high F1-score and accuracy.

# %%
print("Xgboost Metric on Test")
print(classification_report(y_test_b, classifier_b.predict(x_test_b), target_names=['Not Fraud', 'Fraud']))
confusion_matrix = ConfusionMatrixDisplay.from_estimator(classifier_b, x_test_b, y_test_b, display_labels=['Not Fraud', 'Fraud'], cmap='Blues')
# Out:
# Xgboost Metric on Test
#               precision    recall  f1-score   support
#
#    Not Fraud       0.92      0.96      0.94        73
#        Fraud       0.95      0.91      0.93        69
#
#     accuracy                           0.94       142
#    macro avg       0.94      0.94      0.94       142
# weighted avg       0.94      0.94      0.94       142

# %% [markdown]
# Based on the results from above, here's an overall observation focusing on which model is best when:
#
# When dealing with the **imbalanced dataset**, all models (Logistic Regression, Shallow Neural Net, Random Forest, Gradient Boosting, Linear SVC, and XGBoost) showed good overall accuracy on the majority class ('Not Fraud') but generally had a trade-off between precision and recall for the minority class ('Fraud'). They tended to be more conservative in predicting 'Fraud', leading to lower recall. In this scenario, models like Gradient Boosting and XGBoost seemed to perform slightly better on the 'Fraud' class compared to the simpler models, but still struggled significantly with recall.
#
# When dealing with the **balanced dataset**, all models showed a significant improvement in performance on the minority class ('Fraud'). The metrics (precision, recall, and F1-score) for both classes were more balanced across all models. Among the models tested on the balanced data, the **XGBoost classifier** and the **Random Forest Classifier** appeared to demonstrate slightly higher and more balanced F1-scores for both 'Not Fraud' and 'Fraud' classes on the test set, indicating better overall performance in correctly identifying both types of transactions. The **LinearSVC** also performed very well on the balanced data.
#
# Therefore, the overall observation is that **addressing the class imbalance by creating a balanced dataset is crucial for improving the detection of the minority class ('Fraud')**. When the data is balanced, tree-based ensemble methods like **XGBoost and Random Forest**, along with **Linear Support Vector Machine**, appear to be the most effective models for this particular fraud detection task, demonstrating a better balance between precision and recall for both classes. For situations where high recall for the minority class is critical (minimizing false negatives), models trained on the balanced dataset are preferred, and XGBoost, Random Forest, and LinearSVC are strong contenders. For situations where overall accuracy on imbalanced data is acceptable and computational resources are limited, simpler models might be considered, but they will likely miss a significant number of fraudulent transactions.

# %% [markdown]
# # Overall Observations
#
# - The models demonstrate competitive performance on the balanced dataset, with balanced precision, recall, and F1-scores for both classes.
# - The choice of the best model depends on the specific goals and trade-offs between precision and recall.
#
# # Factor Influencing Model Selection
#
# The considerations and factors involved in choosing the best model based on the specific goals and trade-offs between precision and recall:
#
# ## Precision and Recall:
# - **Precision:** Precision is the ratio of true positive predictions to the total predicted positives. It focuses on minimizing false positives. In the context of fraud detection, a high precision means that when the model predicts a transaction as fraudulent, it is highly likely to be accurate.
#
# - **Recall:** Recall is the ratio of true positive predictions to the total actual positives. It focuses on minimizing false negatives. In fraud detection, high recall implies that the model is effective in identifying most of the actual fraudulent transactions.
#
# ## Trade-offs:
# ### 1. Precision-Focused Approach:
#    - **Scenario:** If the business priority is to minimize the number of false positives (genuine transactions misclassified as fraud), a precision-focused approach is appropriate.
#    - **Implication:** This ensures that when the model flags a transaction as fraudulent, it is very likely to be an actual case of fraud. However, it may result in missing some actual fraud cases (lower recall).
#
# ### 2. Recall-Focused Approach:
#    - **Scenario:** If the business is more concerned about capturing as many fraud cases as possible, even at the cost of a higher false positive rate, a recall-focused approach is suitable.
#    - **Implication:** This maximizes the identification of actual fraud cases but may lead to more false positives, as the model might be less stringent in its criteria for flagging transactions.
#
# ## Business Decision:
# - **Precision-Recall Trade-off:** The business decision hinges on the acceptable trade-off between precision and recall. It's about finding the right balance based on the business's risk tolerance and the cost associated with false positives and false negatives.
#
# - **Consideration of Business Goals:** The choice of the best model should align with the overarching business goals. For instance, a financial institution might prioritize minimizing false positives to avoid inconveniencing legitimate customers, while an e-commerce platform might prioritize recall to prevent fraudulent transactions.
#
# In essence, the decision-making process involves a thoughtful evaluation of the specific business context, risks, and priorities. It's not a one-size-fits-all scenario, and the chosen model should align with the unique requirements and constraints of the business at hand.
